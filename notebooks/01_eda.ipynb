# %%
import pandas as pd

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("../data/raw/game.csv")

# %%
df.head(10)
# Out:
#    season_id  team_id_home team_abbreviation_home           team_name_home  \
# 0      21946    1610610035                    HUS          Toronto Huskies
# 1      21946    1610610034                    BOM        St. Louis Bombers
# 2      21946    1610610032                    PRO  Providence Steamrollers
# 3      21946    1610610025                    CHS            Chicago Stags
# 4      21946    1610610028                    DEF          Detroit Falcons
# 5      21946    1610610026                    CLR         Cleveland Rebels
# 6      21946    1610610031                    PIT       Pittsburgh Ironmen
# 7      21946    1610612738                    BOS           Boston Celtics
# 8      21946    1610610028                    DEF          Detroit Falcons
# 9      21946    1610610032                    PRO  Providence Steamrollers
#
#     game_id            game_date matchup_home wl_home  min  fgm_home  ...  \
# ...

# %%
df_clean = df.dropna()
print(df_clean)
# Out:
#        season_id  team_id_home team_abbreviation_home  \
# 14166      41979    1610612747                    LAL
# 14167      41979    1610612755                    PHL
# 14170      41979    1610612755                    PHL
# 14171      31979    1610616833                    EST
# 14172      31979    1610616833                    EST
# ...          ...           ...                    ...
# 65691      42022    1610612743                    DEN
# 65692      42022    1610612743                    DEN
# 65693      42022    1610612748                    MIA
# 65694      42022    1610612748                    MIA
# 65695      42022    1610612743                    DEN
#
#                 team_name_home   game_id            game_date matchup_home  \
# 14166       Los Angeles Lakers  47900044  1980-05-07 00:00:00  LAL vs. PHL
# 14167       Philadelphia 76ers  47900045  1980-05-10 00:00:00  PHL vs. LAL
# 14170       Philadelphia 76ers  47900048  1980-05-16 00:00:00  PHL vs. LAL
# ...

# %%
df = df.dropna(axis=1, how="all")
print(df.head(3))
# Out:
#    season_id  team_id_home team_abbreviation_home           team_name_home  \
# 0      21946    1610610035                    HUS          Toronto Huskies
# 1      21946    1610610034                    BOM        St. Louis Bombers
# 2      21946    1610610032                    PRO  Providence Steamrollers
#
#     game_id            game_date matchup_home wl_home  min  fgm_home  ...  \
# 0  24600001  1946-11-01 00:00:00  HUS vs. NYK       L    0      25.0  ...
# 1  24600003  1946-11-02 00:00:00  BOM vs. PIT       W    0      20.0  ...
# 2  24600002  1946-11-02 00:00:00  PRO vs. BOS       W    0      21.0  ...
#
#    reb_away  ast_away  stl_away  blk_away  tov_away  pf_away  pts_away  \
# 0       NaN       NaN       NaN       NaN       NaN      NaN      68.0
# 1       NaN       NaN       NaN       NaN       NaN     25.0      51.0
# 2       NaN       NaN       NaN       NaN       NaN      NaN      53.0
#
#    plus_minus_away  video_available_away     season_type
# ...

# %%
df = df.drop(columns=["game_date"])
print(df.head(3))
# Out:
#    season_id  team_id_home team_abbreviation_home           team_name_home  \
# 0      21946    1610610035                    HUS          Toronto Huskies
# 1      21946    1610610034                    BOM        St. Louis Bombers
# 2      21946    1610610032                    PRO  Providence Steamrollers
#
#     game_id matchup_home wl_home  min  fgm_home  fga_home  ...  reb_away  \
# 0  24600001  HUS vs. NYK       L    0      25.0       NaN  ...       NaN
# 1  24600003  BOM vs. PIT       W    0      20.0      59.0  ...       NaN
# 2  24600002  PRO vs. BOS       W    0      21.0       NaN  ...       NaN
#
#    ast_away  stl_away  blk_away  tov_away  pf_away  pts_away  plus_minus_away  \
# 0       NaN       NaN       NaN       NaN      NaN      68.0                2
# 1       NaN       NaN       NaN       NaN     25.0      51.0               -5
# 2       NaN       NaN       NaN       NaN      NaN      53.0               -6
#
#    video_available_away     season_type
# ...

# %%
df_all_cleaned = df.dropna(how="all")
print(df_all_cleaned.iloc[:10, :10])
# Out:
#    season_id  team_id_home team_abbreviation_home           team_name_home  \
# 0      21946    1610610035                    HUS          Toronto Huskies
# 1      21946    1610610034                    BOM        St. Louis Bombers
# 2      21946    1610610032                    PRO  Providence Steamrollers
# 3      21946    1610610025                    CHS            Chicago Stags
# 4      21946    1610610028                    DEF          Detroit Falcons
# 5      21946    1610610026                    CLR         Cleveland Rebels
# 6      21946    1610610031                    PIT       Pittsburgh Ironmen
# 7      21946    1610612738                    BOS           Boston Celtics
# 8      21946    1610610028                    DEF          Detroit Falcons
# 9      21946    1610610032                    PRO  Providence Steamrollers
#
#     game_id matchup_home wl_home  min  fgm_home  fga_home
# 0  24600001  HUS vs. NYK       L    0      25.0       NaN
# ...

# %%
df_cleaned = df.drop(columns=["fga_home", "fg_pct_home", "fg3m_home", "fg3a_home", "fg3_pct_home", "reb_away", "ast_away", "stl_away", "blk_away", "tov_away"])
print(df_cleaned.iloc[:10, :50])
# Out:
#    season_id  team_id_home team_abbreviation_home           team_name_home  \
# 0      21946    1610610035                    HUS          Toronto Huskies
# 1      21946    1610610034                    BOM        St. Louis Bombers
# 2      21946    1610610032                    PRO  Providence Steamrollers
# 3      21946    1610610025                    CHS            Chicago Stags
# 4      21946    1610610028                    DEF          Detroit Falcons
# 5      21946    1610610026                    CLR         Cleveland Rebels
# 6      21946    1610610031                    PIT       Pittsburgh Ironmen
# 7      21946    1610612738                    BOS           Boston Celtics
# 8      21946    1610610028                    DEF          Detroit Falcons
# 9      21946    1610610032                    PRO  Providence Steamrollers
#
#     game_id matchup_home wl_home  min  fgm_home  ftm_home  ...  ftm_away  \
# ...

# %%
import matplotlib as mpl
